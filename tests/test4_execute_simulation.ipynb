# %% [markdown]
# #### テスト - シミュレーション実施

# %%
import sys
sys.path.append("../") # homeディレクトリをpathに追加

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import japanize_matplotlib
import pprint
# import warnings
# warnings.simplefilter('error')

from utils import const, init_functions
# from utils.init_functions import *
from models import GasAdosorption_Breakthrough_simulator

# %cd c:\Users\jfe144674\WorkSpace\PJ493_DataAssim_CatalyticReactor\codes_PJ493\05_gas_adsorption_3dim
# Out:
# c:\Users\jfe144674\WorkSpace\PJ493_DataAssim_CatalyticReactor\codes_PJ493\05_gas_adsorption_3dim

# %%
cond_id = "2_20_test_num_section"
self = GasAdosorption_Breakthrough_simulator(cond_id)

# %% [markdown]
# - シミュレーション実施

# %%
self.execute_simulation()
# Out:
# (1/3) simulation...
# (2/3) csv output...
# (3/3) png output...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\jfe144674\WorkSpace\PJ493_DataAssim_CatalyticReactor\.pj493env\lib\site-packages\pandas\core\indexes\base.py:3361, in Index.get_loc(self, key, method, tolerance)
#    3360 try:
# -> 3361     return self._engine.get_loc(casted_key)
#    3362 except KeyError as err:
#
# File c:\Users\jfe144674\WorkSpace\PJ493_DataAssim_CatalyticReactor\.pj493env\lib\site-packages\pandas\_libs\index.pyx:76, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\jfe144674\WorkSpace\PJ493_DataAssim_CatalyticReactor\.pj493env\lib\site-packages\pandas\_libs\index.pyx:108, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'temp_reached_10'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [3], in <module>
# ----> 1 self.execute_simulation()
#
# File c:\Users\jfe144674\WorkSpace\PJ493_DataAssim_CatalyticReactor\codes_PJ493\05_gas_adsorption_3dim\tests\..\models.py:175, in GasAdosorption_Breakthrough_simulator.execute_simulation(self, filtered_states, output_foldapath)
#     172 for value in self.common_conds["LOC_CENCER"].values(): # 温度計に最も近いセルを計算
#     173     plot_target_sec.append(np.argmin(np.abs(loc_cells - value)))
# --> 175 plot_csv.plot_csv_files(tgt_foldapath = output_foldapath + mode + "/",
#     176                         unit_dict=const.UNIT,
#     177                         data_dir=const.DATA_DIR,
#     178                         tgt_sections=plot_target_sec
#     179                         )
#
# File c:\Users\jfe144674\WorkSpace\PJ493_DataAssim_CatalyticReactor\codes_PJ493\05_gas_adsorption_3dim\tests\..\utils\plot_csv.py:60, in plot_csv_files(tgt_foldapath, unit_dict, data_dir, tgt_sections)
#      58 for stream in range(1,3):
#      59     for section in tgt_sections:
# ---> 60         plt.plot(df[f"temp_reached_{stream}{section}"],
#      61                 label = f"(str,sec) = ({stream}, {section})",
#      62                 linestyle = linestyle_dict[section],
#      63                 c = color_dict[stream],
#      64                 )
#      65 for stream in range(1,3):
#      66     for section in tgt_sections:
#
# File c:\Users\jfe144674\WorkSpace\PJ493_DataAssim_CatalyticReactor\.pj493env\lib\site-packages\pandas\core\frame.py:3458, in DataFrame.__getitem__(self, key)
#    3456 if self.columns.nlevels > 1:
#    3457     return self._getitem_multilevel(key)
# -> 3458 indexer = self.columns.get_loc(key)
#    3459 if is_integer(indexer):
#    3460     indexer = [indexer]
#
# File c:\Users\jfe144674\WorkSpace\PJ493_DataAssim_CatalyticReactor\.pj493env\lib\site-packages\pandas\core\indexes\base.py:3363, in Index.get_loc(self, key, method, tolerance)
#    3361         return self._engine.get_loc(casted_key)
#    3362     except KeyError as err:
# -> 3363         raise KeyError(key) from err
#    3365 if is_scalar(key) and isna(key) and not self.hasnans:
#    3366     raise KeyError(key)
#
# KeyError: 'temp_reached_10'
