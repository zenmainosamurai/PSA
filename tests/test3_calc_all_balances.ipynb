# %% [markdown]
# #### テスト - 全体のマテバラ・熱バラ計算

# %%
import sys
sys.path.append("../") # homeディレクトリをpathに追加

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import japanize_matplotlib
import pprint
# import warnings
# warnings.simplefilter('error')

from utils import const, init_functions
# from utils.init_functions import *
from models import GasAdosorption_Breakthrough_simulator

# %cd c:\Users\jfe144674\WorkSpace\PJ493_DataAssim_CatalyticReactor\codes_PJ493\05_gas_adsorption_3dim
# Out:
# c:\Users\jfe144674\WorkSpace\PJ493_DataAssim_CatalyticReactor\codes_PJ493\05_gas_adsorption_3dim

# %%
cond_id = "tmp"
self = GasAdosorption_Breakthrough_simulator(cond_id)

# %% [markdown]
# - 状態変数の初期化

# %%
variables = self.init_variables()
variables
# Out:
# {'temp': {1: {1: 18, 2: 18, 3: 18},
#   2: {1: 18, 2: 18, 3: 18},
#   3: {1: 18, 2: 18, 3: 18}}}

# %% [markdown]
# - 全体のマテバラ・熱バラ

# %%
# 1回目
variables_1, all_output_1 = self.calc_all_cell_balance(variables=variables)
print("1回目")
pprint.pprint(variables_1)
pprint.pprint(all_output_1)
# 2回目
variables_2, all_output_2 = self.calc_all_cell_balance(variables=variables_1)
print("2回目")
pprint.pprint(variables_2)
pprint.pprint(all_output_2)
# 3回目
variables_3, all_output_3 = self.calc_all_cell_balance(variables=variables_2)
print("3回目")
pprint.pprint(variables_3)
pprint.pprint(all_output_3)
# 4回目
variables_4, all_output_4 = self.calc_all_cell_balance(variables=variables_3)
print("4回目")
pprint.pprint(variables_4)
pprint.pprint(all_output_4)
# 5回目
variables_5, all_output_5 = self.calc_all_cell_balance(variables=variables_4)
print("5回目")
pprint.pprint(variables_5)
pprint.pprint(all_output_5)
# Out:
# 1回目
# {'temp': {1: {1: 18.204554606339197, 2: 18.0, 3: 18.0},
#           2: {1: 18.204554606339197, 2: 18.0, 3: 18.0},
#           3: {1: 18.0, 2: 18.0, 3: 18.0}}}
# {'heat': {1: {1: {'hw1': 9.565942715373192, 'temp_reached': 18.204554606339197},
#               2: {'hw1': 9.414580578046639, 'temp_reached': 18.0},
#               3: {'hw1': 9.414580578046639, 'temp_reached': 18.0}},
#           2: {1: {'hw1': 7.87802836049426, 'temp_reached': 18.204554606339197},
#               2: {'hw1': 6.875207043005647, 'temp_reached': 18.0},
#               3: {'hw1': 6.875207043005647, 'temp_reached': 18.0}},
#           3: {1: {'Hbb': 0.0, 'temp_reached': 18.0},
#               2: {'Hbb': 0.0, 'temp_reached': 18.0},
#               3: {'Hbb': 0, 'temp_reached': 18.0}}},
#  'material': {1: {1: {'accum_adsorp_amt': 45.36840081386092,
#                       'adsorp_amt_estimate': 55.0,
#                       'gas_cp': 0.9546400449600001,
#                       'gas_density': 1.49617759296,
#                       'inflow_fr_co2': 55.0,
#                       'inflow_fr_n2': 70.0,
#                       'inflow_mf_co2': 0.44,
#                       'inflow_mf_n2': 0.56,
#                       'outflow_fr_co2': 0.0,
#                       'outflow_fr_n2': 70.0,
#                       'outflow_mf_co2': 0.0,
#                       'outflow_mf_n2': 1.0},
#                   2: {'accum_adsorp_amt': 45.30728970274981,
#                       'adsorp_amt_estimate': 0.0,
#                       'gas_cp': 1.041366956,
#                       'gas_density': 1.192247215,
#                       'inflow_fr_co2': 0.0,
#                       'inflow_fr_n2': 70.0,
#                       'inflow_mf_co2': 0.0,
#                       'inflow_mf_n2': 1.0,
#                       'outflow_fr_co2': 0.0,
#                       'outflow_fr_n2': 70.0,
#                       'outflow_mf_co2': 0.0,
#                       'outflow_mf_n2': 1.0},
#                   3: {'accum_adsorp_amt': 45.30728970274981,
#                       'adsorp_amt_estimate': 0.0,
#                       'gas_cp': 1.041366956,
#                       'gas_density': 1.192247215,
#                       'inflow_fr_co2': 0.0,
#                       'inflow_fr_n2': 70.0,
#                       'inflow_mf_co2': 0.0,
#                       'inflow_mf_n2': 1.0,
#                       'outflow_fr_co2': 0.0,
#                       'outflow_fr_n2': 70.0,
#                       'outflow_mf_co2': 0.0,
#                       'outflow_mf_n2': 1.0}},
#               2: {1: {'accum_adsorp_amt': 45.36840081386092,
#                       'adsorp_amt_estimate': 164.99999999999997,
#                       'gas_cp': 0.9546400449600001,
#                       'gas_density': 1.49617759296,
#                       'inflow_fr_co2': 164.99999999999997,
#                       'inflow_fr_n2': 210.0,
#                       'inflow_mf_co2': 0.43999999999999995,
#                       'inflow_mf_n2': 0.56,
#                       'outflow_fr_co2': 0.0,
#                       'outflow_fr_n2': 210.0,
#                       'outflow_mf_co2': 0.0,
#                       'outflow_mf_n2': 1.0},
#                   2: {'accum_adsorp_amt': 45.30728970274981,
#                       'adsorp_amt_estimate': 0.0,
#                       'gas_cp': 1.041366956,
#                       'gas_density': 1.192247215,
#                       'inflow_fr_co2': 0.0,
#                       'inflow_fr_n2': 210.0,
#                       'inflow_mf_co2': 0.0,
#                       'inflow_mf_n2': 1.0,
#                       'outflow_fr_co2': 0.0,
#                       'outflow_fr_n2': 210.0,
#                       'outflow_mf_co2': 0.0,
#                       'outflow_mf_n2': 1.0},
#                   3: {'accum_adsorp_amt': 45.30728970274981,
#                       'adsorp_amt_estimate': 0.0,
#                       'gas_cp': 1.041366956,
#                       'gas_density': 1.192247215,
#                       'inflow_fr_co2': 0.0,
#                       'inflow_fr_n2': 210.0,
#                       'inflow_mf_co2': 0.0,
#                       'inflow_mf_n2': 1.0,
#                       'outflow_fr_co2': 0.0,
#                       'outflow_fr_n2': 210.0,
#                       'outflow_mf_co2': 0.0,
#                       'outflow_mf_n2': 1.0}}}}
# 2回目
# {'temp': {1: {1: 18.409109212678395, 2: 18.0, 3: 18.0},
#           2: {1: 18.40897864103023, 2: 18.0, 3: 18.0},
#           3: {1: 18.00001620813997, 2: 18.0, 3: 18.0}}}
# {'heat': {1: {1: {'hw1': 9.566650701141066, 'temp_reached': 18.409109212678395},
#               2: {'hw1': 9.414580578046639, 'temp_reached': 18.0},
#               3: {'hw1': 9.414580578046639, 'temp_reached': 18.0}},
#           2: {1: {'hw1': 7.878482881124003, 'temp_reached': 18.40897864103023},
#               2: {'hw1': 6.875207043005647, 'temp_reached': 18.0},
#               3: {'hw1': 6.875207043005647, 'temp_reached': 18.0}},
#           3: {1: {'Hbb': 0.0, 'temp_reached': 18.00001620813997},
#               2: {'Hbb': 0.0, 'temp_reached': 18.0},
#               3: {'Hbb': 0, 'temp_reached': 18.0}}},
#  'material': {1: {1: {'accum_adsorp_amt': 45.074677357495354,
#                       'adsorp_amt_estimate': 55.0,
#                       'gas_cp': 0.9546400449600001,
#                       'gas_density': 1.49617759296,
#                       'inflow_fr_co2': 55.0,
#                       'inflow_fr_n2': 70.0,
#                       'inflow_mf_co2': 0.44,
#                       'inflow_mf_n2': 0.56,
#                       'outflow_fr_co2': 0.0,
#                       'outflow_fr_n2': 70.0,
#                       'outflow_mf_co2': 0.0,
#                       'outflow_mf_n2': 1.0},
#                   2: {'accum_adsorp_amt': 45.30728970274981,
#                       'adsorp_amt_estimate': 0.0,
#                       'gas_cp': 1.041366956,
#                       'gas_density': 1.192247215,
#                       'inflow_fr_co2': 0.0,
#                       'inflow_fr_n2': 70.0,
#                       'inflow_mf_co2': 0.0,
#                       'inflow_mf_n2': 1.0,
#                       'outflow_fr_co2': 0.0,
#                       'outflow_fr_n2': 70.0,
#                       'outflow_mf_co2': 0.0,
#                       'outflow_mf_n2': 1.0},
#                   3: {'accum_adsorp_amt': 45.30728970274981,
#                       'adsorp_amt_estimate': 0.0,
#                       'gas_cp': 1.041366956,
#                       'gas_density': 1.192247215,
#                       'inflow_fr_co2': 0.0,
#                       'inflow_fr_n2': 70.0,
#                       'inflow_mf_co2': 0.0,
#                       'inflow_mf_n2': 1.0,
#                       'outflow_fr_co2': 0.0,
#                       'outflow_fr_n2': 70.0,
#                       'outflow_mf_co2': 0.0,
#                       'outflow_mf_n2': 1.0}},
#               2: {1: {'accum_adsorp_amt': 45.074677357495354,
#                       'adsorp_amt_estimate': 164.99999999999997,
#                       'gas_cp': 0.9546400449600001,
#                       'gas_density': 1.49617759296,
#                       'inflow_fr_co2': 164.99999999999997,
#                       'inflow_fr_n2': 210.0,
#                       'inflow_mf_co2': 0.43999999999999995,
#                       'inflow_mf_n2': 0.56,
#                       'outflow_fr_co2': 0.0,
#                       'outflow_fr_n2': 210.0,
#                       'outflow_mf_co2': 0.0,
#                       'outflow_mf_n2': 1.0},
#                   2: {'accum_adsorp_amt': 45.30728970274981,
#                       'adsorp_amt_estimate': 0.0,
#                       'gas_cp': 1.041366956,
#                       'gas_density': 1.192247215,
#                       'inflow_fr_co2': 0.0,
#                       'inflow_fr_n2': 210.0,
#                       'inflow_mf_co2': 0.0,
#                       'inflow_mf_n2': 1.0,
#                       'outflow_fr_co2': 0.0,
#                       'outflow_fr_n2': 210.0,
#                       'outflow_mf_co2': 0.0,
#                       'outflow_mf_n2': 1.0},
#                   3: {'accum_adsorp_amt': 45.30728970274981,
#                       'adsorp_amt_estimate': 0.0,
#                       'gas_cp': 1.041366956,
#                       'gas_density': 1.192247215,
#                       'inflow_fr_co2': 0.0,
#                       'inflow_fr_n2': 210.0,
#                       'inflow_mf_co2': 0.0,
#                       'inflow_mf_n2': 1.0,
#                       'outflow_fr_co2': 0.0,
#                       'outflow_fr_n2': 210.0,
#                       'outflow_mf_co2': 0.0,
#                       'outflow_mf_n2': 1.0}}}}
# 3回目
# {'temp': {1: {1: 18.61366369517789, 2: 18.0, 3: 18.0},
#           2: {1: 18.613272223474688, 2: 18.0, 3: 18.0},
#           3: {1: 18.000048612266596, 2: 17.999999999933348, 3: 18.0}}}
# {'heat': {1: {1: {'hw1': 9.567359684421112, 'temp_reached': 18.61366369517789},
#               2: {'hw1': 9.414580578046639, 'temp_reached': 18.0},
#               3: {'hw1': 9.414580578046639, 'temp_reached': 18.0}},
#           2: {1: {'hw1': 7.878937750689142, 'temp_reached': 18.613272223474688},
#               2: {'hw1': 6.875207043005647, 'temp_reached': 18.0},
#               3: {'hw1': 6.875207043005647, 'temp_reached': 18.0}},
#           3: {1: {'Hbb': 6.811331829999469e-07,
#                   'temp_reached': 18.000048612266596},
#               2: {'Hbb': 0.0, 'temp_reached': 17.999999999933348},
#               3: {'Hbb': 0, 'temp_reached': 18.0}}},
#  'material': {1: {1: {'accum_adsorp_amt': 44.78211427138215,
#                       'adsorp_amt_estimate': 55.0,
#                       'gas_cp': 0.9546400449600001,
#                       'gas_density': 1.49617759296,
#                       'inflow_fr_co2': 55.0,
#                       'inflow_fr_n2': 70.0,
#                       'inflow_mf_co2': 0.44,
#                       'inflow_mf_n2': 0.56,
#                       'outflow_fr_co2': 0.0,
#                       'outflow_fr_n2': 70.0,
#                       'outflow_mf_co2': 0.0,
#                       'outflow_mf_n2': 1.0},
#                   2: {'accum_adsorp_amt': 45.30728970274981,
#                       'adsorp_amt_estimate': 0.0,
#                       'gas_cp': 1.041366956,
#                       'gas_density': 1.192247215,
#                       'inflow_fr_co2': 0.0,
#                       'inflow_fr_n2': 70.0,
#                       'inflow_mf_co2': 0.0,
#                       'inflow_mf_n2': 1.0,
#                       'outflow_fr_co2': 0.0,
#                       'outflow_fr_n2': 70.0,
#                       'outflow_mf_co2': 0.0,
#                       'outflow_mf_n2': 1.0},
#                   3: {'accum_adsorp_amt': 45.30728970274981,
#                       'adsorp_amt_estimate': 0.0,
#                       'gas_cp': 1.041366956,
#                       'gas_density': 1.192247215,
#                       'inflow_fr_co2': 0.0,
#                       'inflow_fr_n2': 70.0,
#                       'inflow_mf_co2': 0.0,
#                       'inflow_mf_n2': 1.0,
#                       'outflow_fr_co2': 0.0,
#                       'outflow_fr_n2': 70.0,
#                       'outflow_mf_co2': 0.0,
#                       'outflow_mf_n2': 1.0}},
#               2: {1: {'accum_adsorp_amt': 44.7823006506462,
#                       'adsorp_amt_estimate': 164.99999999999997,
#                       'gas_cp': 0.9546400449600001,
#                       'gas_density': 1.49617759296,
#                       'inflow_fr_co2': 164.99999999999997,
#                       'inflow_fr_n2': 210.0,
#                       'inflow_mf_co2': 0.43999999999999995,
#                       'inflow_mf_n2': 0.56,
#                       'outflow_fr_co2': 0.0,
#                       'outflow_fr_n2': 210.0,
#                       'outflow_mf_co2': 0.0,
#                       'outflow_mf_n2': 1.0},
#                   2: {'accum_adsorp_amt': 45.30728970274981,
#                       'adsorp_amt_estimate': 0.0,
#                       'gas_cp': 1.041366956,
#                       'gas_density': 1.192247215,
#                       'inflow_fr_co2': 0.0,
#                       'inflow_fr_n2': 210.0,
#                       'inflow_mf_co2': 0.0,
#                       'inflow_mf_n2': 1.0,
#                       'outflow_fr_co2': 0.0,
#                       'outflow_fr_n2': 210.0,
#                       'outflow_mf_co2': 0.0,
#                       'outflow_mf_n2': 1.0},
#                   3: {'accum_adsorp_amt': 45.30728970274981,
#                       'adsorp_amt_estimate': 0.0,
#                       'gas_cp': 1.041366956,
#                       'gas_density': 1.192247215,
#                       'inflow_fr_co2': 0.0,
#                       'inflow_fr_n2': 210.0,
#                       'inflow_mf_co2': 0.0,
#                       'inflow_mf_n2': 1.0,
#                       'outflow_fr_co2': 0.0,
#                       'outflow_fr_n2': 210.0,
#                       'outflow_mf_co2': 0.0,
#                       'outflow_mf_n2': 1.0}}}}
# 4回目
# {'temp': {1: {1: 18.8182179302056, 2: 18.0, 3: 18.0},
#           2: {1: 18.81743547292002, 2: 17.999999999999964, 3: 18.0},
#           3: {1: 18.000097200241665, 2: 17.99999999973346, 3: 18.0}}}
# {'heat': {1: {1: {'hw1': 9.568069665492784, 'temp_reached': 18.8182179302056},
#               2: {'hw1': 9.414580578046639, 'temp_reached': 18.0},
#               3: {'hw1': 9.414580578046639, 'temp_reached': 18.0}},
#           2: {1: {'hw1': 7.8793929686830175, 'temp_reached': 18.81743547292002},
#               2: {'hw1': 6.875207043005647, 'temp_reached': 17.999999999999964},
#               3: {'hw1': 6.875207043005647, 'temp_reached': 18.0}},
#           3: {1: {'Hbb': 2.042891617230727e-06,
#                   'temp_reached': 18.000097200241665},
#               2: {'Hbb': -2.801012529441642e-12,
#                   'temp_reached': 17.99999999973346},
#               3: {'Hbb': 0, 'temp_reached': 18.0}}},
#  'material': {1: {1: {'accum_adsorp_amt': 44.49071173159084,
#                       'adsorp_amt_estimate': 55.0,
#                       'gas_cp': 0.9546400449600001,
#                       'gas_density': 1.49617759296,
#                       'inflow_fr_co2': 55.0,
#                       'inflow_fr_n2': 70.0,
#                       'inflow_mf_co2': 0.44,
#                       'inflow_mf_n2': 0.56,
#                       'outflow_fr_co2': 0.0,
#                       'outflow_fr_n2': 70.0,
#                       'outflow_mf_co2': 0.0,
#                       'outflow_mf_n2': 1.0},
#                   2: {'accum_adsorp_amt': 45.30728970274981,
#                       'adsorp_amt_estimate': 0.0,
#                       'gas_cp': 1.041366956,
#                       'gas_density': 1.192247215,
#                       'inflow_fr_co2': 0.0,
#                       'inflow_fr_n2': 70.0,
#                       'inflow_mf_co2': 0.0,
#                       'inflow_mf_n2': 1.0,
#                       'outflow_fr_co2': 0.0,
#                       'outflow_fr_n2': 70.0,
#                       'outflow_mf_co2': 0.0,
#                       'outflow_mf_n2': 1.0},
#                   3: {'accum_adsorp_amt': 45.30728970274981,
#                       'adsorp_amt_estimate': 0.0,
#                       'gas_cp': 1.041366956,
#                       'gas_density': 1.192247215,
#                       'inflow_fr_co2': 0.0,
#                       'inflow_fr_n2': 70.0,
#                       'inflow_mf_co2': 0.0,
#                       'inflow_mf_n2': 1.0,
#                       'outflow_fr_co2': 0.0,
#                       'outflow_fr_n2': 70.0,
#                       'outflow_mf_co2': 0.0,
#                       'outflow_mf_n2': 1.0}},
#               2: {1: {'accum_adsorp_amt': 44.49126830290627,
#                       'adsorp_amt_estimate': 164.99999999999997,
#                       'gas_cp': 0.9546400449600001,
#                       'gas_density': 1.49617759296,
#                       'inflow_fr_co2': 164.99999999999997,
#                       'inflow_fr_n2': 210.0,
#                       'inflow_mf_co2': 0.43999999999999995,
#                       'inflow_mf_n2': 0.56,
#                       'outflow_fr_co2': 0.0,
#                       'outflow_fr_n2': 210.0,
#                       'outflow_mf_co2': 0.0,
#                       'outflow_mf_n2': 1.0},
#                   2: {'accum_adsorp_amt': 45.30728970274981,
#                       'adsorp_amt_estimate': 0.0,
#                       'gas_cp': 1.041366956,
#                       'gas_density': 1.192247215,
#                       'inflow_fr_co2': 0.0,
#                       'inflow_fr_n2': 210.0,
#                       'inflow_mf_co2': 0.0,
#                       'inflow_mf_n2': 1.0,
#                       'outflow_fr_co2': 0.0,
#                       'outflow_fr_n2': 210.0,
#                       'outflow_mf_co2': 0.0,
#                       'outflow_mf_n2': 1.0},
#                   3: {'accum_adsorp_amt': 45.30728970274981,
#                       'adsorp_amt_estimate': 0.0,
#                       'gas_cp': 1.041366956,
#                       'gas_density': 1.192247215,
#                       'inflow_fr_co2': 0.0,
#                       'inflow_fr_n2': 210.0,
#                       'inflow_mf_co2': 0.0,
#                       'inflow_mf_n2': 1.0,
#                       'outflow_fr_co2': 0.0,
#                       'outflow_fr_n2': 210.0,
#                       'outflow_mf_co2': 0.0,
#                       'outflow_mf_n2': 1.0}}}}
# 5回目
# {'temp': {1: {1: 19.02277179433667, 2: 18.0, 3: 18.0},
#           2: {1: 19.02146850845979, 2: 17.99999999999983, 3: 18.0},
#           3: {1: 18.000161959942037, 2: 17.999999999333824, 3: 18.0}}}
# {'heat': {1: {1: {'hw1': 9.56878064463387, 'temp_reached': 19.02277179433667},
#               2: {'hw1': 9.414580578046639, 'temp_reached': 18.0},
#               3: {'hw1': 9.414580578046639, 'temp_reached': 18.0}},
#           2: {1: {'hw1': 7.879848534599192, 'temp_reached': 19.02146850845979},
#               2: {'hw1': 6.875207043005647, 'temp_reached': 17.99999999999983},
#               3: {'hw1': 6.875207043005647, 'temp_reached': 18.0}},
#           3: {1: {'Hbb': 4.084768002909051e-06,
#                   'temp_reached': 18.000161959942037},
#               2: {'Hbb': -1.1201064122852179e-11,
#                   'temp_reached': 17.999999999333824},
#               3: {'Hbb': 0, 'temp_reached': 18.0}}},
#  'material': {1: {1: {'accum_adsorp_amt': 44.20046991108277,
#                       'adsorp_amt_estimate': 55.0,
#                       'gas_cp': 0.9546400449600001,
#                       'gas_density': 1.49617759296,
#                       'inflow_fr_co2': 55.0,
#                       'inflow_fr_n2': 70.0,
#                       'inflow_mf_co2': 0.44,
#                       'inflow_mf_n2': 0.56,
#                       'outflow_fr_co2': 0.0,
#                       'outflow_fr_n2': 70.0,
#                       'outflow_mf_co2': 0.0,
#                       'outflow_mf_n2': 1.0},
#                   2: {'accum_adsorp_amt': 45.30728970274981,
#                       'adsorp_amt_estimate': 0.0,
#                       'gas_cp': 1.041366956,
#                       'gas_density': 1.192247215,
#                       'inflow_fr_co2': 0.0,
#                       'inflow_fr_n2': 70.0,
#                       'inflow_mf_co2': 0.0,
#                       'inflow_mf_n2': 1.0,
#                       'outflow_fr_co2': 0.0,
#                       'outflow_fr_n2': 70.0,
#                       'outflow_mf_co2': 0.0,
#                       'outflow_mf_n2': 1.0},
#                   3: {'accum_adsorp_amt': 45.30728970274981,
#                       'adsorp_amt_estimate': 0.0,
#                       'gas_cp': 1.041366956,
#                       'gas_density': 1.192247215,
#                       'inflow_fr_co2': 0.0,
#                       'inflow_fr_n2': 70.0,
#                       'inflow_mf_co2': 0.0,
#                       'inflow_mf_n2': 1.0,
#                       'outflow_fr_co2': 0.0,
#                       'outflow_fr_n2': 70.0,
#                       'outflow_mf_co2': 0.0,
#                       'outflow_mf_n2': 1.0}},
#               2: {1: {'accum_adsorp_amt': 44.20157792820621,
#                       'adsorp_amt_estimate': 164.99999999999997,
#                       'gas_cp': 0.9546400449600001,
#                       'gas_density': 1.49617759296,
#                       'inflow_fr_co2': 164.99999999999997,
#                       'inflow_fr_n2': 210.0,
#                       'inflow_mf_co2': 0.43999999999999995,
#                       'inflow_mf_n2': 0.56,
#                       'outflow_fr_co2': 0.0,
#                       'outflow_fr_n2': 210.0,
#                       'outflow_mf_co2': 0.0,
#                       'outflow_mf_n2': 1.0},
#                   2: {'accum_adsorp_amt': 45.30728970274981,
#                       'adsorp_amt_estimate': 0.0,
#                       'gas_cp': 1.041366956,
#                       'gas_density': 1.192247215,
#                       'inflow_fr_co2': 0.0,
#                       'inflow_fr_n2': 210.0,
#                       'inflow_mf_co2': 0.0,
#                       'inflow_mf_n2': 1.0,
#                       'outflow_fr_co2': 0.0,
#                       'outflow_fr_n2': 210.0,
#                       'outflow_mf_co2': 0.0,
#                       'outflow_mf_n2': 1.0},
#                   3: {'accum_adsorp_amt': 45.30728970274981,
#                       'adsorp_amt_estimate': 0.0,
#                       'gas_cp': 1.041366956,
#                       'gas_density': 1.192247215,
#                       'inflow_fr_co2': 0.0,
#                       'inflow_fr_n2': 210.0,
#                       'inflow_mf_co2': 0.0,
#                       'inflow_mf_n2': 1.0,
#                       'outflow_fr_co2': 0.0,
#                       'outflow_fr_n2': 210.0,
#                       'outflow_mf_co2': 0.0,
#                       'outflow_mf_n2': 1.0}}}}
